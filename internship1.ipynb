# %% [markdown]
# <a href="https://colab.research.google.com/github/mathewalex262006/ict/blob/main/internship1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("we are starting")
# Out:
# we are starting

# %%
"hi9hiuh"
# Out:
# 'hi9hiuh'

# %%
68754674768
# Out:
# 68754674768

# %%
print("helow","how","are","you",sep="_")
# Out:
# helow_how_are_you

# %%
name = "mathew"
roll_no = 74
collage = ("assunption collage chaganassery")
print(name,roll_no,collage)
# Out:
# mathew 74 assunption collage chaganassery

# %%
print(f"i am {name} and roll number is {roll_no}. i am from {collage}.")
# Out:
# i am mathew and roll number is 74. i am from assunption collage chaganassery.

# %%
firstname = input("enter your first name")
secondname = input("enter your second name")
print(f"your full name is {firstname} {secondname}")
# Out:
# enter your first namemathew
# enter your second namealex
# your full name is mathew alex

# %%
type(firstname)
# Out:
# str

# %%
income = int (input("enter your incom"))
expense = int( input("enter your expense"))
print(f"your savings is {income - expense}")
# Out:
# enter your incom100000
# enter your expense60000
# your savings is 40000

# %%
a = 10
b = 3
a + b
# Out:
# 13

# %%
a - b
# Out:
# 7

# %%
a/b
# Out:
# 3.3333333333333335

# %%
a%b
# Out:
# 1

# %%
a**b
# Out:
# 1000

# %%
a//b
# Out:
# 3

# %%
print(a==b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %%
print(a>5 and b>7)
# Out:
# False

# %%
print( a>5 or b>7)
# Out:
# True

# %%
new="learning is fun"
print(len(new))
# Out:
# 15

# %%
groceries = ["milk","bread","eggs","bun"]
groceries.append("tomato")
groceries.insert(2,"pen")
groceries
# Out:
# ['milk', 'bread', 'pen', 'eggs', 'bun', 'tomato']

# %%
groceries.remove("milk")

# %%
groceries.pop(1)
groceries
# Out:
# ['bread', 'eggs', 'bun', 'tomato']

# %%
groceries.count("bun")
# Out:
# 1

# %%
groceries.index("bread")
# Out:
# 0

# %%
groceries.sort()
groceries
# Out:
# ['bread', 'bun', 'eggs', 'tomato']

# %%
groceries.reverse()
groceries
# Out:
# ['tomato', 'eggs', 'bun', 'bread']

# %%
groceries[0]
# Out:
# 'milk'

# %%
groceries.insert(1,"pineapple")
groceries
# Out:
# ['milk', 'pineapple', 'bread', 'eggs', 'pen']

# %%
len (groceries)
# Out:
# 5

# %%
groceries.count("milk")
# Out:
# 1

# %%
groceries.pop()
# Out:
# 'pen'

# %%
groceries.pop(2)
# Out:
# 'eggs'

# %%
groceries
# Out:
# ['bread']

# %%
groceries = ["milk","bread","eggs"]
groceries.sort(reverse=True)

# %%
groceries
# Out:
# ['milk', 'eggs', 'bread']

# %%
mystring = "python is an easy programing language"
mystring.replace("python","java")
# Out:
# 'java is an easy programing language'

# %%
mystring = "python is an easy programing language"
print(mystring.lower())
# Out:
# python is an easy programing language

# %%
print(mystring.upper())
# Out:
# PYTHON IS AN EASY PROGRAMING LANGUAGE

# %%
print(mystring.title())
# Out:
# Python Is An Easy Programing Language

# %%
print(mystring.capitalize())
# Out:
# Python is an easy programing language

# %%
print(mystring.swapcase())
# Out:
# PYTHON IS AN EASY PROGRAMING LANGUAGE

# %%
mystring.find("all")
# Out:
# -1

# %%
mystring.find("is")
# Out:
# 7

# %%
len(mystring)
# Out:
# 37

# %%
mystring.split()
# Out:
# ['python', 'is', 'an', 'easy', 'programing', 'language']

# %%
mystring[1:10]
# Out:
# 'ython is '

# %%
mystring[1:]
# Out:
# 'ython is an easy programing language'

# %%
mystring[:20]
# Out:
# 'python is an easy pr'

# %%
mystring[1:20:2]
# Out:
# 'yhni nes r'

# %%
type(groceries)
# Out:
# list

# %%
groceries = ("milk","bread","eggs")
groceries
# Out:
# ('milk', 'bread', 'eggs')

# %%
type(groceries)
# Out:
# tuple

# %%
groceries_2=tuple(groceries)

# %%
info={
    "name":"mathew",
    "age":74,
    "rollno":"assumptions",
    "blood group":"B+",
}
info["name"]
# Out:
# 'mathew'

# %%
info.keys()
# Out:
# dict_keys(['name', 'age', 'rollno', 'blood group'])

# %%
info.values()
# Out:
# dict_values(['mathew', 74, 'assumptions', 'B+'])

# %%
info["blood group"]="Rh-"

# %%
info["Dept"]="CompSc"

# %%
info
# Out:
# {'name': 'mathew',
#  'rollno': 'assumptions',
#  'blood group': 'Rh-',
#  'Dept': 'CompSc'}

# %%
info.pop("age")
# Out:
# 74

# %%
a=110
b=100
if a>b:
  print("A is greater")
else:
  print("B is greater")
# Out:
# A is greater

# %%
score=77
if score>=90:
  print("Grade A")
elif score>=80:
  print("Grade B")
elif score>=70:
  print("Grade C")
elif score>=60:
  print("Grade D")
else:
  print("You have failed")
# Out:
# Grade C

# %%
color = "Red"
if color=="Green":
  print("Go")
elif color=="Yellow":
  print("Slow Down")
elif color=="Red":
    print("Stop")
else:
  print("Wrong Signal")
# Out:
# Stop

# %%
price=int(input("Enter your bill amount"))
if price>=2999:
  price=price-500
  print("Bill amount is ",price)
elif price>=1999:
  price=price-250
  print("Bill amount is ",price)
elif price>=750:
  price=price*0.9
  print("Bill amount is ",price)
else:
  print("Error occured")
# Out:
# Enter your bill amount1000
# Bill amount is  900.0
